# %% [markdown]
# # 1. Import and Install Dependencies

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
len(results.right_hand_landmarks.landmark)
# Out:
# 21

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.58495414,  0.49350491, -0.79960537, ...,  0.25368878,
#         0.21489833, -0.05880157])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.58495414,  0.49350491, -0.79960537, ...,  0.25368878,
#         0.21489833, -0.05880157])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
DATA_PATH = 'MP_Data'

# Actions that we try to detect
actions = np.array(['hello', 'thanks', 'iloveyou'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30

# %%
for action in actions:
    try:
        os.makedirs(os.path.join(DATA_PATH, action))
    except FileExistsError:
        pass

# %%
for action in actions:
    action_path = os.path.join(DATA_PATH, action)
    if len(os.listdir(action_path)) > 0:
        dirmax = np.max(np.array(os.listdir(action_path)).astype(int))
    else:
        dirmax = 0
    
    for sequence in range(1, no_sequences + 1):
        try:
            os.makedirs(os.path.join(action_path, str(dirmax + sequence)))
        except FileExistsError:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(start_folder, start_folder+no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                os.makedirs(os.path.dirname(npy_path), exist_ok=True)
                np.save(npy_path, keypoints)
                # np.save(npy_path, keypoints)


                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
# Out:
# WARNING:tensorflow:From e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (90, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (90,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (90, 30, 1662)

# %%
#jvrhrjrvbjhej
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (5, 3)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# WARNING:tensorflow:From e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# Out:
# WARNING:tensorflow:From e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# WARNING:tensorflow:From e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3/3 [==============================] - 9s 120ms/step - loss: 1.3174 - categorical_accuracy: 0.2235
# Epoch 2/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 3.0703 - categorical_accuracy: 0.4824
# Epoch 3/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 4.4613 - categorical_accuracy: 0.4000
# Epoch 4/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 2.4115 - categorical_accuracy: 0.3176
# Epoch 5/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 1.5883 - categorical_accuracy: 0.2941
# Epoch 6/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 2.6727 - categorical_accuracy: 0.2824
# Epoch 7/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 1.5530 - categorical_accuracy: 0.2706
# Epoch 8/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 1.1509 - categorical_accuracy: 0.3059
# Epoch 9/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 1.3033 - categorical_accuracy: 0.2353
# Epoch 10/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 1.1653 - categorical_accuracy: 0.3294
# Epoch 11/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 1.1622 - categorical_accuracy: 0.2118
# Epoch 12/2000
# 3/3 [==============================] - 0s 175ms/step - loss: 1.1064 - categorical_accuracy: 0.4706
# Epoch 13/2000
# 3/3 [==============================] - 1s 262ms/step - loss: 1.0193 - categorical_accuracy: 0.3529
# Epoch 14/2000
# 3/3 [==============================] - 1s 195ms/step - loss: 0.9466 - categorical_accuracy: 0.6235
# Epoch 15/2000
# 3/3 [==============================] - 1s 199ms/step - loss: 0.9629 - categorical_accuracy: 0.6235
# Epoch 16/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 0.8890 - categorical_accuracy: 0.6471
# Epoch 17/2000
2000
# 3/3 [==============================] - 0s 153ms/step - loss: 0.4716 - categorical_accuracy: 0.7412
# Epoch 48/2000
# 3/3 [==============================] - 1s 209ms/step - loss: 0.4494 - categorical_accuracy: 0.7059
# Epoch 49/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 0.4747 - categorical_accuracy: 0.7412
# Epoch 50/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 0.4301 - categorical_accuracy: 0.7529
# Epoch 51/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 0.4324 - categorical_accuracy: 0.7412
# Epoch 52/2000
# 3/3 [==============================] - 1s 159ms/step - loss: 0.3933 - categorical_accuracy: 0.8118
# Epoch 53/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 0.4166 - categorical_accuracy: 0.7647
# Epoch 54/2000
# 3/3 [==============================] - 0s 167ms/step - loss: 0.3880 - categorical_accuracy: 0.7882
# Epoch 55/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 0.4114 - categorical_accuracy: 0.7765
# Epoch 56/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 0.4039 - categorical_accuracy: 0.8353
# Epoch 57/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 0.3950 - categorical_accuracy: 0.7882
# Epoch 58/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.4344 - categorical_accuracy: 0.7765
# Epoch 59/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 0.4356 - categorical_accuracy: 0.7647
# Epoch 60/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 0.4176 - categorical_accuracy: 0.7412
# Epoch 61/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.4414 - categorical_accuracy: 0.8353
# Epoch 62/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.5169 - categorical_accuracy: 0.7647
# Epoch 63/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 0.9897 - categorical_accuracy: 0.6353
# Epoch 64/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 0.6890 - categorical_accuracy: 0.6471
# Epoch 65/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.3954 - categorical_accuracy: 0.8471
# Epoch 66/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 0.5187 - categorical_accuracy: 0.7647
# Epoch 67/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 0.6759 - categorical_accuracy: 0.6118
# Epoch 68/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 0.5779 - categorical_accuracy: 0.6706
# Epoch 69/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.4590 - categorical_accuracy: 0.7765
# Epoch 70/2000
# 3/3 [==============================] - 1s 220ms/step - loss: 0.4504 - categorical_accuracy: 0.7647
# Epoch 71/2000
# 3/3 [==============================] - 1s 188ms/step - loss: 0.5085 - categorical_accuracy: 0.7412
# Epoch 72/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 0.4737 - categorical_accuracy: 0.7647
# Epoch 73/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 0.4296 - categorical_accuracy: 0.8000
# Epoch 74/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 0.4061 - categorical_accuracy: 0.8235
# Epoch 75/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.3720 - categorical_accuracy: 0.8353
# Epoch 76/2000
# 3/3 [==============================] - 0s 158ms/step - loss: 0.3530 - categorical_accuracy: 0.8235
# Epoch 77/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 0.3282 - categorical_accuracy: 0.8118
# Epoch 78/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 0.3186 - categorical_accuracy: 0.8353
# Epoch 79/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.2926 - categorical_accuracy: 0.8353
# Epoch 80/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 0.2896 - categorical_accuracy: 0.8588
# Epoch 81/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 0.2778 - categorical_accuracy: 0.8706
# Epoch 82/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 0.2958 - categorical_accuracy: 0.8588
# Epoch 83/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 0.2948 - categorical_accuracy: 0.8824
# Epoch 84/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 0.2888 - categorical_accuracy: 0.8824
# Epoch 85/2000
# 3/3 [==============================] - 1s 175ms/step - loss: 0.2987 - categorical_accuracy: 0.8706
# Epoch 86/2000
# 3/3 [==============================] - 0s 157ms/step - loss: 0.2959 - categorical_accuracy: 0.8941
# Epoch 87/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 0.5375 - categorical_accuracy: 0.7294
# Epoch 88/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.2877 - categorical_accuracy: 0.8824
# Epoch 89/2000
# 3/3 [==============================] - 1s 164ms/step - loss: 0.3319 - categorical_accuracy: 0.8824
# Epoch 90/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 0.3109 - categorical_accuracy: 0.8706
# Epoch 91/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.2702 - categorical_accuracy: 0.9059
# Epoch 92/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 0.2454 - categorical_accuracy: 0.9059
# Epoch 93/2000
# 3/3 [==============================] - 1s 166ms/step - loss: 0.2345 - categorical_accuracy: 0.8824
# Epoch 94/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 0.2533 - categorical_accuracy: 0.8824
# Epoch 95/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 0.2748 - categorical_accuracy: 0.8941
# Epoch 96/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 0.2123 - categorical_accuracy: 0.8824
# Epoch 97/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 0.2406 - categorical_accuracy: 0.8941
# Epoch 98/2000
# 3/3 [==============================] - 0s 145ms/step - loss: 0.2346 - categorical_accuracy: 0.8941
# Epoch 99/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.3077 - categorical_accuracy: 0.9059
# Epoch 100/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 0.7371 - categorical_accuracy: 0.7294
# Epoch 101/2000
# 3/3 [==============================] - 1s 156ms/step - loss: 0.4220 - categorical_accuracy: 0.8353
# Epoch 102/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 0.7427 - categorical_accuracy: 0.7059
# Epoch 103/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 0.6448 - categorical_accuracy: 0.6588
# Epoch 104/2000
# 3/3 [==============================] - 0s 170ms/step - loss: 0.5030 - categorical_accuracy: 0.7176
# Epoch 105/2000
# 3/3 [==============================] - 1s 168ms/step - loss: 0.4187 - categorical_accuracy: 0.8235
# Epoch 106/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 0.3623 - categorical_accuracy: 0.8706
# Epoch 107/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.4396 - categorical_accuracy: 0.7294
# Epoch 108/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 0.3981 - categorical_accuracy: 0.7765
# Epoch 109/2000
# 3/3 [==============================] - 0s 153ms/step - loss:
2000
# 3/3 [==============================] - 0s 109ms/step - loss: 1.0990 - categorical_accuracy: 0.3412
# Epoch 174/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 1.0991 - categorical_accuracy: 0.3412
# Epoch 175/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 1.0991 - categorical_accuracy: 0.3412
# Epoch 176/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 1.0990 - categorical_accuracy: 0.3412
# Epoch 177/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 1.0990 - categorical_accuracy: 0.3412
# Epoch 178/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 1.0990 - categorical_accuracy: 0.3412
# Epoch 179/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 1.0990 - categorical_accuracy: 0.3412
# Epoch 180/2000
# 3/3 [==============================] - 0s 138ms/step - loss: 1.0989 - categorical_accuracy: 0.3412
# Epoch 181/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 1.0989 - categorical_accuracy: 0.3412
# Epoch 182/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 1.0989 - categorical_accuracy: 0.3412
# Epoch 183/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 1.0989 - categorical_accuracy: 0.3412
# Epoch 184/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 1.0989 - categorical_accuracy: 0.3412
# Epoch 185/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.0989 - categorical_accuracy: 0.3412
# Epoch 186/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0989 - categorical_accuracy: 0.3412
# Epoch 187/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.0989 - categorical_accuracy: 0.3412
# Epoch 188/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.0989 - categorical_accuracy: 0.3412
# Epoch 189/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.0988 - categorical_accuracy: 0.3412
# Epoch 190/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 1.0988 - categorical_accuracy: 0.3412
# Epoch 191/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 1.0988 - categorical_accuracy: 0.3412
# Epoch 192/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 1.0988 - categorical_accuracy: 0.3412
# Epoch 193/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 1.0988 - categorical_accuracy: 0.3412
# Epoch 194/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 1.0988 - categorical_accuracy: 0.3412
# Epoch 195/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 1.0988 - categorical_accuracy: 0.3412
# Epoch 196/2000
# 3/3 [==============================] - 1s 171ms/step - loss: 1.0988 - categorical_accuracy: 0.3412
# Epoch 197/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 1.0988 - categorical_accuracy: 0.3412
# Epoch 198/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 1.0988 - categorical_accuracy: 0.3412
# Epoch 199/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.0987 - categorical_accuracy: 0.3412
# Epoch 200/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0988 - categorical_accuracy: 0.3412
# Epoch 201/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0987 - categorical_accuracy: 0.3412
# Epoch 202/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0987 - categorical_accuracy: 0.3412
# Epoch 203/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 1.0987 - categorical_accuracy: 0.3412
# Epoch 204/2000
# 3/3 [==============================] - 0s 133ms/step - loss: 1.0987 - categorical_accuracy: 0.3412
# Epoch 205/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 1.0987 - categorical_accuracy: 0.3412
# Epoch 206/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0987 - categorical_accuracy: 0.3412
# Epoch 207/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0987 - categorical_accuracy: 0.3412
# Epoch 208/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0987 - categorical_accuracy: 0.3412
# Epoch 209/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 210/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 211/2000
# 3/3 [==============================] - 0s 137ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 212/2000
# 3/3 [==============================] - 1s 161ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 213/2000
# 3/3 [==============================] - 0s 138ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 214/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 215/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 216/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 217/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 218/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 219/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 220/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 221/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 222/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 223/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.0985 - categorical_accuracy: 0.3412
# Epoch 224/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 1.0986 - categorical_accuracy: 0.3412
# Epoch 225/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0985 - categorical_accuracy: 0.3412
# Epoch 226/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0985 - categorical_accuracy: 0.3412
# Epoch 227/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0985 - categorical_accuracy: 0.3412
# Epoch 228/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0985 - categorical_accuracy: 0.3412
# Epoch 229/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.0985 - categorical_accuracy: 0.3412
# Epoch 230/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0985 - categorical_accuracy: 0.3412
# Epoch 231/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 1.0985 - categorical_accuracy: 0.3412
# Epoch 232/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.0985 - categorical_accuracy: 0.3412
# Epoch 233/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0984 - categorical_accuracy: 0.3412
# Epoch 234/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.0985 - categorical_accuracy: 0.3412
# Epoch 235/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0984 - categorical_accuracy: 0.3412
# Epoch 236/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0984 - categorical_accuracy: 0.3412
# Epoch 237/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0984 - categorical_accuracy: 0.3412
# Epoch 238/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.0984 - categorical_accuracy: 0.3412
# Epoch 239/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 1.0984 - categorical_accuracy: 0.3412
# Epoch 240/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0984 - categorical_accuracy: 0.3412
# Epoch 241/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0984 - categorical_accuracy: 0.3412
# Epoch 242/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 1.0984 - categorical_accuracy: 0.3412
# Epoch 243/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0983 - categorical_accuracy: 0.3412
# Epoch 244/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0984 - categorical_accuracy: 0.3412
# Epoch 245/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 1.0983 - categorical_accuracy: 0.3412
# Epoch 246/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 1.0983 - categorical_accuracy: 0.3412
# Epoch 247/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 1.0983 - categorical_accuracy: 0.3412
# Epoch 248/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 1.0983 - categorical_accuracy: 0.3412
# Epoch 249/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 1.0983 - categorical_accuracy: 0.3412
# Epoch 250/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 1.0983 - categorical_accuracy: 0.3412
# Epoch 251/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 1.0983 - categorical_accuracy: 0.3412
# Epoch 252/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 1.0983 - categorical_accuracy: 0.3412
# Epoch 253/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 1.0982 - categorical_accuracy: 0.3412
# Epoch 254/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 1.0982 - categorical_accuracy: 0.3412
# Epoch 255/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 1.0982 - categorical_accuracy: 0.3412
# Epoch 256/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0982 - categorical_accuracy: 0.3412
# Epoch 257/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0982 - categorical_accuracy: 0.3412
# Epoch 258/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0982 - categorical_accuracy: 0.3412
# Epoch 259/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0981 - categorical_accuracy: 0.3412
# Epoch 260/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 1.0982 - categorical_accuracy: 0.3412
# Epoch 261/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0982 - categorical_accuracy: 0.3412
# Epoch 262/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0981 - categorical_accuracy: 0.3412
# Epoch 263/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0981 - categorical_accuracy: 0.3412
# Epoch 264/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0981 - categorical_accuracy: 0.3412
# Epoch 265/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0981 - categorical_accuracy: 0.3412
# Epoch 266/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0981 - categorical_accuracy: 0.3412
# Epoch 267/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.0981 - categorical_accuracy: 0.3412
# Epoch 268/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0981 - categorical_accuracy: 0.3412
# Epoch 269/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.0980 - categorical_accuracy: 0.3412
# Epoch 270/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0980 - categorical_accuracy: 0.3412
# Epoch 271/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0980 - categorical_accuracy: 0.3412
# Epoch 272/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.0980 - categorical_accuracy: 0.3412
# Epoch 273/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.0979 - categorical_accuracy: 0.3412
# Epoch 274/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.0979 - categorical_accuracy: 0.3412
# Epoch 275/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0979 - categorical_accuracy: 0.3412
# Epoch 276/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0979 - categorical_accuracy: 0.3412
# Epoch 277/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0979 - categorical_accuracy: 0.3412
# Epoch 278/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0978 - categorical_accuracy: 0.3412
# Epoch 279/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 1.0978 - categorical_accuracy: 0.3412
# Epoch 280/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0977 - categorical_accuracy: 0.3412
# Epoch 281/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0976 - categorical_accuracy: 0.3412
# Epoch 282/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 1.0976 - categorical_accuracy: 0.3412
# Epoch 283/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 1.0976 - categorical_accuracy: 0.3412
# Epoch 284/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0975 - categorical_accuracy: 0.3412
# Epoch 285/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 1.0975 - categorical_accuracy: 0.3412
# Epoch 286/2000
# 3/3 [==============================] - 1s 187ms/step - loss: 1.0974 - categorical_accuracy: 0.3412
# Epoch 287/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 1.0974 - categorical_accuracy: 0.3412
# Epoch 288/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 1.0973 - categorical_accuracy: 0.3412
# Epoch 289/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 1.0972 - categorical_accuracy: 0.3412
# Epoch 290/2000
# 3/3 [==============================] - 1s 219ms/step - loss: 1.0972 - categorical_accuracy: 0.3412
# Epoch 291/2000
# 3/3 [==============================] - 1s 151ms/step - loss: 1.0971 - categorical_accuracy: 0.3412
# Epoch 292/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 1.0971 - categorical_accuracy: 0.3412
# Epoch 293/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 1.0970 - categorical_accuracy: 0.3412
# Epoch 294/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 1.0969 - categorical_accuracy: 0.3412
# Epoch 295/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 1.0968 - categorical_accuracy: 0.3412
# Epoch 296/2000
# 3/3 [==============================] - 1s 141ms/step - loss: 1.0968 - categorical_accuracy: 0.3412
# Epoch 297/2000
# 3/3 [==============================] - 1s 207ms/step - loss: 1.0968 - categorical_accuracy: 0.3412
# Epoch 298/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 1.0966 - categorical_accuracy: 0.3412
# Epoch 299/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 1.0965 - categorical_accuracy: 0.3412
# Epoch 300/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 1.0964 - categorical_accuracy: 0.3412
# Epoch 301/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.0963 - categorical_accuracy: 0.3412
# Epoch 302/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0962 - categorical_accuracy: 0.3412
# Epoch 303/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.0959 - categorical_accuracy: 0.3412
# Epoch 304/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0958 - categorical_accuracy: 0.3412
# Epoch 305/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.0958 - categorical_accuracy: 0.3412
# Epoch 306/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 1.0954 - categorical_accuracy: 0.3412
# Epoch 307/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 1.0952 - categorical_accuracy: 0.3412
# Epoch 308/2000
# 3/3 [==============================] - 0s 164ms/step - loss: 1.0949 - categorical_accuracy: 0.3412
# Epoch 309/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 1.0948 - categorical_accuracy: 0.3412
# Epoch 310/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.0950 - categorical_accuracy: 0.3412
# Epoch 311/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.0945 - categorical_accuracy: 0.3412
# Epoch 312/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0936 - categorical_accuracy: 0.3412
# Epoch 313/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0933 - categorical_accuracy: 0.3412
# Epoch 314/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0937 - categorical_accuracy: 0.3412
# Epoch 315/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.0931 - categorical_accuracy: 0.3412
# Epoch 316/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0962 - categorical_accuracy: 0.3412
# Epoch 317/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0935 - categorical_accuracy: 0.3412
# Epoch 318/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.0932 - categorical_accuracy: 0.3412
# Epoch 319/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0937 - categorical_accuracy: 0.3412
# Epoch 320/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.0929 - categorical_accuracy: 0.3412
# Epoch 321/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0925 - categorical_accuracy: 0.3412
# Epoch 322/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.0915 - categorical_accuracy: 0.3412
# Epoch 323/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0895 - categorical_accuracy: 0.3412
# Epoch 324/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 1.0903 - categorical_accuracy: 0.3412
# Epoch 325/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0891 - categorical_accuracy: 0.3412
# Epoch 326/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0905 - categorical_accuracy: 0.3412
# Epoch 327/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0892 - categorical_accuracy: 0.3412
# Epoch 328/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0879 - categorical_accuracy: 0.3412
# Epoch 329/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.0875 - categorical_accuracy: 0.3412
# Epoch 330/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 1.0876 - categorical_accuracy: 0.3412
# Epoch 331/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0865 - categorical_accuracy: 0.3412
# Epoch 332/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.0850 - categorical_accuracy: 0.3412
# Epoch 333/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0860 - categorical_accuracy: 0.3412
# Epoch 334/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 1.0837 - categorical_accuracy: 0.3412
# Epoch 335/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0837 - categorical_accuracy: 0.3412
# Epoch 336/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.0832 - categorical_accuracy: 0.3647
# Epoch 337/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 1.0830 - categorical_accuracy: 0.5765
# Epoch 338/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0820 - categorical_accuracy: 0.4706
# Epoch 339/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.0799 - categorical_accuracy: 0.5294
# Epoch 340/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0794 - categorical_accuracy: 0.5882
# Epoch 341/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0789 - categorical_accuracy: 0.5412
# Epoch 342/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0748 - categorical_accuracy: 0.6118
# Epoch 343/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 1.0730 - categorical_accuracy: 0.6588
# Epoch 344/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0798 - categorical_accuracy: 0.5294
# Epoch 345/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0767 - categorical_accuracy: 0.4824
# Epoch 346/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0828 - categorical_accuracy: 0.6000
# Epoch 347/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0753 - categorical_accuracy: 0.5412
# Epoch 348/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0755 - categorical_accuracy: 0.6353
# Epoch 349/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0745 - categorical_accuracy: 0.5529
# Epoch 350/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0730 - categorical_accuracy: 0.6000
# Epoch 351/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 1.0725 - categorical_accuracy: 0.6353
# Epoch 352/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0703 - categorical_accuracy: 0.6000
# Epoch 353/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 1.0713 - categorical_accuracy: 0.6000
# Epoch 354/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0671 - categorical_accuracy: 0.6235
# Epoch 355/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.0681 - categorical_accuracy: 0.6353
# Epoch 356/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0615 - categorical_accuracy: 0.6588
# Epoch 357/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0607 - categorical_accuracy: 0.6471
# Epoch 358/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.0616 - categorical_accuracy: 0.6118
# Epoch 359/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0650 - categorical_accuracy: 0.5647
# Epoch 360/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.0581 - categorical_accuracy: 0.6353
# Epoch 361/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0572 - categorical_accuracy: 0.5765
# Epoch 362/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 1.0553 - categorical_accuracy: 0.6118
# Epoch 363/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0540 - categorical_accuracy: 0.6706
# Epoch 364/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 1.0529 - categorical_accuracy: 0.6471
# Epoch 365/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0530 - categorical_accuracy: 0.6706
# Epoch 366/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 1.0549 - categorical_accuracy: 0.6588
# Epoch 367/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0756 - categorical_accuracy: 0.4471
# Epoch 368/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.0600 - categorical_accuracy: 0.6235
# Epoch 369/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 1.0549 - categorical_accuracy: 0.6000
# Epoch 370/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.0518 - categorical_accuracy: 0.6471
# Epoch 371/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0492 - categorical_accuracy: 0.6471
# Epoch 372/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 1.0480 - categorical_accuracy: 0.6471
# Epoch 373/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.0465 - categorical_accuracy: 0.6588
# Epoch 374/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0420 - categorical_accuracy: 0.6588
# Epoch 375/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.0357 - categorical_accuracy: 0.6588
# Epoch 376/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.0345 - categorical_accuracy: 0.6588
# Epoch 377/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0328 - categorical_accuracy: 0.6588
# Epoch 378/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0316 - categorical_accuracy: 0.6588
# Epoch 379/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0263 - categorical_accuracy: 0.6588
# Epoch 380/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.0264 - categorical_accuracy: 0.6588
# Epoch 381/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0245 - categorical_accuracy: 0.6588
# Epoch 382/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.0204 - categorical_accuracy: 0.6588
# Epoch 383/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 1.0154 - categorical_accuracy: 0.6588
# Epoch 384/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0196 - categorical_accuracy: 0.6588
# Epoch 385/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0163 - categorical_accuracy: 0.6588
# Epoch 386/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 1.0148 - categorical_accuracy: 0.6588
# Epoch 387/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.0072 - categorical_accuracy: 0.6588
# Epoch 388/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.0050 - categorical_accuracy: 0.6588
# Epoch 389/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0003 - categorical_accuracy: 0.6588
# Epoch 390/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.0176 - categorical_accuracy: 0.6353
# Epoch 391/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0242 - categorical_accuracy: 0.6471
# Epoch 392/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0309 - categorical_accuracy: 0.5765
# Epoch 393/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.0063 - categorical_accuracy: 0.6353
# Epoch 394/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.9962 - categorical_accuracy: 0.6588
# Epoch 395/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.9935 - categorical_accuracy: 0.6588
# Epoch 396/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.9884 - categorical_accuracy: 0.6588
# Epoch 397/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.9868 - categorical_accuracy: 0.6588
# Epoch 398/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.9821 - categorical_accuracy: 0.6588
# Epoch 399/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.9785 - categorical_accuracy: 0.6588
# Epoch 400/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.9805 - categorical_accuracy: 0.6588
# Epoch 401/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0169 - categorical_accuracy: 0.5529
# Epoch 402/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.0684 - categorical_accuracy: 0.3765
# Epoch 403/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.9834 - categorical_accuracy: 0.5765
# Epoch 404/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0380 - categorical_accuracy: 0.4235
# Epoch 405/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.9903 - categorical_accuracy: 0.6471
# Epoch 406/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.9647 - categorical_accuracy: 0.6588
# Epoch 407/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.9662 - categorical_accuracy: 0.5765
# Epoch 408/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.9621 - categorical_accuracy: 0.6588
# Epoch 409/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.9506 - categorical_accuracy: 0.6000
# Epoch 410/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.9146 - categorical_accuracy: 0.6588
# Epoch 411/2000
# 3/3 [==============================] - 0s 152ms/step - loss: 0.8749 - categorical_accuracy: 0.6588
# Epoch 412/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.7691 - categorical_accuracy: 0.6588
# Epoch 413/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.7983 - categorical_accuracy: 0.6235
# Epoch 414/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.9363 - categorical_accuracy: 0.5059
# Epoch 415/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 1.2879 - categorical_accuracy: 0.3294
# Epoch 416/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.9213 - categorical_accuracy: 0.4941
# Epoch 417/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.0328 - categorical_accuracy: 0.3529
# Epoch 418/2000
# ...
# Epoch 1513/2000
# 3/3 [==============================] - 1s 163ms/step - loss: 0.1542 - categorical_accuracy: 0.9412
# Epoch 1514/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.1611 - categorical_accuracy: 0.9529
# Epoch 1515/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.1597 - categorical_accuracy: 0.9412
# Epoch 1516/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.1519 - categorical_accuracy: 0.9176
# Epoch 1517/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1601 - categorical_accuracy: 0.9529
# Epoch 1518/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.1766 - categorical_accuracy: 0.9294
# Epoch 1519/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 0.2135 - categorical_accuracy: 0.9412
# Epoch 1520/2000
# 3/3 [==============================] - 0s 169ms/step - loss: 0.3265 - categorical_accuracy: 0.9059
# Epoch 1521/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.4325 - categorical_accuracy: 0.8118
# Epoch 1522/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 0.5108 - categorical_accuracy: 0.8353
# Epoch 1523/2000
# 3/3 [==============================] - 1s 174ms/step - loss: 0.3227 - categorical_accuracy: 0.8706
# Epoch 1524/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 0.4822 - categorical_accuracy: 0.8000
# Epoch 1525/2000
# 3/3 [==============================] - 0s 141ms/step - loss:
2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.1324 - categorical_accuracy: 0.9294
# Epoch 1565/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1288 - categorical_accuracy: 0.9412
# Epoch 1566/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1720 - categorical_accuracy: 0.9294
# Epoch 1567/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1523 - categorical_accuracy: 0.9412
# Epoch 1568/2000
# 3/3 [==============================] - 0s 136ms/step - loss: 0.1297 - categorical_accuracy: 0.9412
# Epoch 1569/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 0.1286 - categorical_accuracy: 0.9412
# Epoch 1570/2000
# 3/3 [==============================] - 1s 147ms/step - loss: 0.1342 - categorical_accuracy: 0.9412
# Epoch 1571/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 0.1402 - categorical_accuracy: 0.9294
# Epoch 1572/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.1556 - categorical_accuracy: 0.9412
# Epoch 1573/2000
# 3/3 [==============================] - 0s 150ms/step - loss: 0.2621 - categorical_accuracy: 0.9176
# Epoch 1574/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.2523 - categorical_accuracy: 0.9059
# Epoch 1575/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.1506 - categorical_accuracy: 0.9176
# Epoch 1576/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.1364 - categorical_accuracy: 0.9529
# Epoch 1577/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1532 - categorical_accuracy: 0.9529
# Epoch 1578/2000
# 3/3 [==============================] - 0s 181ms/step - loss: 0.1946 - categorical_accuracy: 0.8824
# Epoch 1579/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.1420 - categorical_accuracy: 0.9176
# Epoch 1580/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.1728 - categorical_accuracy: 0.9176
# Epoch 1581/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.1625 - categorical_accuracy: 0.9529
# Epoch 1582/2000
# 3/3 [==============================] - 1s 162ms/step - loss: 0.1211 - categorical_accuracy: 0.9412
# Epoch 1583/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.1349 - categorical_accuracy: 0.9412
# Epoch 1584/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 0.1281 - categorical_accuracy: 0.9647
# Epoch 1585/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.1298 - categorical_accuracy: 0.9647
# Epoch 1586/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.1187 - categorical_accuracy: 0.9647
# Epoch 1587/2000
# 3/3 [==============================] - 0s 160ms/step - loss: 0.1965 - categorical_accuracy: 0.9294
# Epoch 1588/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 0.1342 - categorical_accuracy: 0.9529
# Epoch 1589/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 0.1031 - categorical_accuracy: 0.9529
# Epoch 1590/2000
# 3/3 [==============================] - 1s 215ms/step - loss: 0.1051 - categorical_accuracy: 0.9647
# Epoch 1591/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.1123 - categorical_accuracy: 0.9647
# Epoch 1592/2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
#
# File e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\keras\src\engine\training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File e:\PERSONAL\AI_DS_ML\Projects\MLProjects\Sign Language Detection LSTM Deep Learning Model\sign\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 596675 (2.28 MB)
# Trainable params: 596675 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
actions[np.argmax(res[4])]
# Out:
# 'hello'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'hello'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('weights.h5')

# %%
del model

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_train)
# Out:
# 3/3 [==============================] - 0s 40ms/step

# %%
ytrue = np.argmax(y_train, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[55,  2],
#         [ 0, 28]],
#
#        [[55,  1],
#         [ 2, 27]],
#
#        [[57,  0],
#         [ 1, 27]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.9647058823529412

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 74ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 117ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 138ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 97ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 95ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 76ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# ...
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 85ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 71ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 52ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 146ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
